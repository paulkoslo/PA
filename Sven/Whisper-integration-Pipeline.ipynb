# %%
# !pip install -q openai-whisper transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 12.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()

# Get the filename
file_path = next(iter(uploaded))
# Out:
#      <input type="file" id="files-cd844858-bde0-4516-9093-2f2afb71db62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd844858-bde0-4516-9093-2f2afb71db62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import whisper

# Load the Whisper model (use "base" or "small")
model = whisper.load_model("base")

# Define transcription function
def transcribe_audio(file_path):
    result = model.transcribe(file_path)
    return result["text"]

# %%
transcription = transcribe_audio(file_path)
print("🎙️ Transcribed Text:")
print(transcription)
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 🎙️ Transcribed Text:
#  Hallo, mein Name ist Zenti. Ich bin 24 Jahre alt und studiere zurzeit an der Katholika School of Business Economics an der Business School in Lissabon Portugal.

# %%
# Reuse the tokenizer you trained earlier (from Tokenizer(num_words=10000, oov_token="<OOV>"))
def preprocess_text_for_lstm_cnn(text, tokenizer, max_len=100):
    seq = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(seq, maxlen=max_len, padding='post')
    return padded

# %%
def predict_with_lstm(transcribed_text):
    padded = preprocess_text_for_lstm_cnn(transcribed_text, tokenizer)
    probs = lstm_model.predict(padded)[0]
    pred = np.argmax(probs)
    return le.classes_[pred], probs

# %%
def predict_with_cnn(transcribed_text):
    padded = preprocess_text_for_lstm_cnn(transcribed_text, tokenizer)
    probs = cnn_model.predict(padded)[0]
    pred = np.argmax(probs)
    return le.classes_[pred], probs

# %%
# Transcribe audio
transcribed_text = transcribe_audio(file_path)
print(f"🎙️ Whisper Transcription:\n{transcribed_text}\n")

# LSTM prediction
lstm_label, lstm_probs = predict_with_lstm(transcribed_text)
print(f"🧠 LSTM Predicted Emotion: {lstm_label}")

# CNN prediction
cnn_label, cnn_probs = predict_with_cnn(transcribed_text)
print(f"🌀 CNN Predicted Emotion: {cnn_label}")

# # Transformer prediction
# bert_label, bert_probs = predict_with_transformer(transcribed_text)
# print(f"⚡ DistilBERT Predicted Emotion: {bert_label}")
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 🎙️ Whisper Transcription:
#  Hallo, mein Name ist Zenti. Ich bin 24 Jahre alt und studiere zurzeit an der Katholika School of Business Economics an der Business School in Lissabon Portugal.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-85fab0634f1f> in <cell line: 0>()
#       4
#       5 # LSTM prediction
# ----> 6 lstm_label, lstm_probs = predict_with_lstm(transcribed_text)
#       7 print(f"🧠 LSTM Predicted Emotion: {lstm_label}")
#       8
#
# <ipython-input-14-5a9a10be474e> in predict_with_lstm(transcribed_text)
#       1 def predict_with_lstm(transcribed_text):
# ----> 2     padded = preprocess_text_for_lstm_cnn(transcribed_text, tokenizer)
# ...
